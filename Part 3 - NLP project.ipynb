# %%
pip install transformers torch
# Out:
# Collecting transformers
#   Downloading transformers-5.12.1-py3-none-any.whl.metadata (33 kB)
# Requirement already satisfied: torch in c:\users\nikki\anaconda3\lib\site-packages (2.11.0)
# Collecting huggingface-hub<2.0,>=1.5.0 (from transformers)
#   Downloading huggingface_hub-1.20.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\nikki\anaconda3\lib\site-packages (from transformers) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\nikki\anaconda3\lib\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\nikki\anaconda3\lib\site-packages (from transformers) (6.0.3)
# Collecting regex>=2025.10.22 (from transformers)
#   Downloading regex-2026.5.9-cp313-cp313-win_amd64.whl.metadata (41 kB)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers)
#   Downloading tokenizers-0.22.2-cp39-abi3-win_amd64.whl.metadata (7.4 kB)
# Requirement already satisfied: typer in c:\users\nikki\anaconda3\lib\site-packages (from transformers) (0.17.4)
# Collecting safetensors>=0.4.3 (from transformers)
#   Downloading safetensors-0.8.0-cp310-abi3-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: tqdm>=4.60 in c:\users\nikki\anaconda3\lib\site-packages (from transformers) (4.67.1)
# Collecting click>=8.4.0 (from huggingface-hub<2.0,>=1.5.0->transformers)
#   Downloading click-8.4.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\nikki\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\nikki\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (2025.10.0)
# Collecting hf-xet<2.0.0,>=1.5.1 (from huggingface-hub<2.0,>=1.5.0->transformers)
#   Downloading hf_xet-1.5.1-cp37-abi3-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\nikki\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Collecting typer (from transformers)
#   Using cached typer-0.25.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\nikki\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: anyio in c:\users\nikki\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.10.0)
# Requirement already satisfied: certifi in c:\users\nikki\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in c:\users\nikki\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in c:\users\nikki\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\nikki\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\nikki\anaconda3\lib\site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in c:\users\nikki\anaconda3\lib\site-packages (from typer->transformers) (14.2.0)
# Collecting annotated-doc>=0.0.2 (from typer->transformers)
#   Using cached annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: setuptools<82 in c:\users\nikki\anaconda3\lib\site-packages (from torch) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\nikki\anaconda3\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\nikki\anaconda3\lib\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in c:\users\nikki\anaconda3\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: colorama in c:\users\nikki\anaconda3\lib\site-packages (from click>=8.4.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.4.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\nikki\anaconda3\lib\site-packages (from rich>=13.8.0->typer->transformers) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\nikki\anaconda3\lib\site-packages (from rich>=13.8.0->typer->transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\nikki\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers) (0.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\nikki\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\nikki\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\nikki\anaconda3\lib\site-packages (from jinja2->torch) (3.0.2)
# Downloading transformers-5.12.1-py3-none-any.whl (11.2 MB)
#    ---------------------------------------- 0.0/11.2 MB ? eta -:--:--
#    ------ --------------------------------- 1.8/11.2 MB 8.8 MB/s eta 0:00:02
#    ------------ --------------------------- 3.4/11.2 MB 8.8 MB/s eta 0:00:01
#    ------------------ --------------------- 5.2/11.2 MB 8.8 MB/s eta 0:00:01
#    ------------------------- -------------- 7.1/11.2 MB 8.8 MB/s eta 0:00:01
#    ------------------------------- -------- 8.9/11.2 MB 8.8 MB/s eta 0:00:01
#    -------------------------------------- - 10.7/11.2 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------------- 11.2/11.2 MB 8.6 MB/s  0:00:01
# Downloading huggingface_hub-1.20.1-py3-none-any.whl (719 kB)
#    ---------------------------------------- 0.0/719.8 kB ? eta -:--:--
#    ---------------------------------------- 719.8/719.8 kB 7.5 MB/s  0:00:00
# Downloading hf_xet-1.5.1-cp37-abi3-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ------------------ --------------------- 1.8/4.0 MB 8.8 MB/s eta 0:00:01
#    ------------------------------------ --- 3.7/4.0 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 7.0 MB/s  0:00:00
# Downloading tokenizers-0.22.2-cp39-abi3-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    -------------------------- ------------- 1.8/2.7 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 6.3 MB/s  0:00:00
# Using cached typer-0.25.1-py3-none-any.whl (58 kB)
# Using cached annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading click-8.4.1-py3-none-any.whl (116 kB)
# Downloading regex-2026.5.9-cp313-cp313-win_amd64.whl (277 kB)
# Downloading safetensors-0.8.0-cp310-abi3-win_amd64.whl (355 kB)
# Installing collected packages: safetensors, regex, hf-xet, click, annotated-doc, typer, huggingface-hub, tokenizers, transformers
#
#   Attempting uninstall: regex
#
#     Found existing installation: regex 2025.9.1
#
#    ---- ----------------------------------- 1/9 [regex]
#     Uninstalling regex-2025.9.1:
#    ---- ----------------------------------- 1/9 [regex]
#       Successfully uninstalled regex-2025.9.1
#    ---- ----------------------------------- 1/9 [regex]
#    ---- ----------------------------------- 1/9 [regex]
#    ---- ----------------------------------- 1/9 [regex]
#    ---- ----------------------------------- 1/9 [regex]
#    ---- ----------------------------------- 1/9 [regex]
#    ---- ----------------------------------- 1/9 [regex]
#    ---- ----------------------------------- 1/9 [regex]
#    ---- ----------------------------------- 1/9 [regex]
#    ---- ----------------------------------- 1/9 [regex]
#    ---- ----------------------------------- 1/9 [regex]
#    ---- ----------------------------------- 1/9 [regex]
#    ---- ----------------------------------- 1/9 [regex]
#    ---- ----------------------------------- 1/9 [regex]
#    ---- ----------------------------------- 1/9 [regex]
#    ---- ----------------------------------- 1/9 [regex]
#    ---- ----------------------------------- 1/9 [regex]
#    ---- ----------------------------------- 1/9 [regex]
#    ---- ----------------------------------- 1/9 [regex]
#    ---- ----------------------------------- 1/9 [regex]
#    ---- ----------------------------------- 1/9 [regex]
#    -------- ------------------------------- 2/9 [hf-xet]
#    -------- ------------------------------- 2/9 [hf-xet]
#   Attempting uninstall: click
#    -------- ------------------------------- 2/9 [hf-xet]
#     Found existing installation: click 8.2.1
#    -------- ------------------------------- 2/9 [hf-xet]
#     Uninstalling click-8.2.1:
#    -------- ------------------------------- 2/9 [hf-xet]
#       Successfully uninstalled click-8.2.1
#    -------- ------------------------------- 2/9 [hf-xet]
#    ------------- -------------------------- 3/9 [click]
#    ------------- -------------------------- 3/9 [click]
#    ----------------- ---------------------- 4/9 [annotated-doc]
#   Attempting uninstall: typer
#    ----------------- ---------------------- 4/9 [annotated-doc]
#     Found existing installation: typer 0.17.4
#    ----------------- ---------------------- 4/9 [annotated-doc]
#     Uninstalling typer-0.17.4:
#    ----------------- ---------------------- 4/9 [annotated-doc]
#       Successfully uninstalled typer-0.17.4
#    ----------------- ---------------------- 4/9 [annotated-doc]
#    ---------------------- ----------------- 5/9 [typer]
#    ---------------------- ----------------- 5/9 [typer]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    -------------------------- ------------- 6/9 [huggingface-hub]
#    ------------------------------- -------- 7/9 [tokenizers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ----------------------------------- ---- 8/9 [transformers]
#    ---------------------------------------- 9/9 [transformers]
#
# Successfully installed annotated-doc-0.0.4 click-8.4.1 hf-xet-1.5.1 huggingface-hub-1.20.1 regex-2026.5.9 safetensors-0.8.0 tokenizers-0.22.2 transformers-5.12.1 typer-0.25.1
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\nikki\anaconda3\Lib\site-packages\~egex'.
#   You can safely remove it manually.

# %%
from transformers import pipeline
classifier = pipeline("zero-shot-classification",
                      model="facebook/bart-large-mnli")
# Out:
# config.json:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# C:\Users\nikki\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:137: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\nikki\.cache\huggingface\hub\models--facebook--bart-large-mnli. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/515 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
