# %% [markdown]
# # Setup for GitHub

# %%
# !git pull origin master
# Out:
# Updating ed90a14..902e21a
# Fast-forward
#  README.md | 15 +++++++++++++--
#  1 file changed, 13 insertions(+), 2 deletions(-)
# From github.com:Nono-bonono/Nono-bonono-nlp_2026_summer_MSc_project
#  * branch            master     -> FETCH_HEAD
#    ed90a14..902e21a  master     -> origin/master

# %%
# Start by importing and finding file path to enable comitting to Git.

import os
print(os.path.abspath('.'))
# Out:
# C:\Users\nikki\BBK MSc - NLP\proj sixty

# %%
os.chdir(r"C:\Users\nikki\BBK MSc - NLP\proj sixty")

# Initialise git
# !git init

# Link to Github
# !git remote add origin git@github.com:Nono-bonono/nlp_2026_summer_MSc_project.git
# Out:
# Initialized empty Git repository in C:/Users/nikki/BBK MSc - NLP/proj sixty/.git/

# %%
# Creating a ReadME
with open("README.md", "w") as f:
    f.write("# My Project\n\nThis is a project that will analyze and evaluate texts.")

# Commit and push
# !git add README.md
# !git commit -m "add README"
# !git push
# Out:
# [master (root-commit) e0e2d1f] add README
#  1 file changed, 3 insertions(+)
#  create mode 100644 README.md
# fatal: The current branch master has no upstream branch.
# To push the current branch and set the remote as upstream, use
#
#     git push --set-upstream origin master
#
# To have this happen automatically for branches without a tracking
# upstream, see 'push.autoSetupRemote' in 'git help config'.

# %%
# !git branch
# Out:
# * master

# %%
# !git remote -v
# Out:
# origin	git@github.com:Nono-bonono/nlp_2026_summer_MSc_project.git (fetch)
# origin	git@github.com:Nono-bonono/nlp_2026_summer_MSc_project.git (push)

# %%
# !git remote set-url origin git@github.com:Nono-bonono/Nono-bonono-nlp_2026_summer_MSc_project.git

# %%
# !git push -u origin master
# Out:
# branch 'master' set up to track 'origin/master'.
# To github.com:Nono-bonono/Nono-bonono-nlp_2026_summer_MSc_project.git
#  * [new branch]      master -> master

# %%
# Creating .gitignore

with open(".gitignore", "w") as f:
    f.write("""# Jupyter
.ipynb_checkpoints/
*/.ipynb_checkpoints/

# Python
__pycache__/
*.py[cod]

# Virtual environments
venv/
env/
.env

# Data files
data/raw/
data/processed/
*.csv
*.parquet
*.pkl
*.pickle

# Models
*.pt
*.pth
*.bin
*.safetensors
models/
embeddings/

# NLP
nltk_data/
corpus/

# Outputs & logs
logs/
runs/
outputs/
*.log
wandb/

# OS
.DS_Store
Thumbs.db
""")
print("✓ .gitignore created")
# Out:
# ✓ .gitignore created

# %%
# Updating .gitignore to include the texts

with open(".gitignore", "a") as f:
    f.write("\n# Book texts\ntexts/\n*.txt\n")
    
print("✓ .gitignore updated")
# Out:
# ✓ .gitignore updated

# %%
# !git add .
# !git commit -m "Copied the classifiers but added unigrams, bi-grams and tri-grams to the vectorizer"
# !git push
# Out:
# warning: in the working copy of 'Part 2 - NLP project.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'github setup and code.ipynb', LF will be replaced by CRLF the next time Git touches it
# [master 8bbd5b5] Copied the classifiers but added unigrams, bi-grams and tri-grams to the vectorizer
#  2 files changed, 76 insertions(+), 38 deletions(-)
# To github.com:Nono-bonono/Nono-bonono-nlp_2026_summer_MSc_project.git
#    54de475..8bbd5b5  master -> master
